# %%
import pandas as pd

# %%
sample = pd.read_json('dataset.json')

# %%
sample
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 1    FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 2    FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 3    FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 4    FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# ..                 ...                                                ...
# 193  FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 194  FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 195  FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 196  FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
# 197  FeatureCollection  {'type': 'Feature', 'properties': {'WARD_NO': ...
#
# [198 rows x 2 columns]

# %%
df = pd.json_normalize(sample['features'])

# %%
df.head(5)
# Out:
#       type properties.WARD_NO      properties.WARD_NAME  \
# 0  Feature                  2          Chowdeswari Ward
# 1  Feature                  3                    Atturu
# 2  Feature                  4  Yelahanka Satellite Town
# 3  Feature                 51               Vijnanapura
# 4  Feature                 53              Basavanapura
#
#   properties.MOVEMENT_ID                            properties.DISPLAY_NAME  \
# 0                      1                            Unnamed Road, Bengaluru
# 1                      2  9th Cross Bhel Layout, Adityanagar, Vidyaranya...
# 2                      3  15th A Cross Road, Yelahanka Satellite Town, Y...
# 3                      4  SP Naidu Layout 4th Cross Street, SP Naidu Lay...
# 4                      5  Medahalli Kadugodi Road, Bharathi Nagar, Krish...
#
#   geometry.type                               geometry.coordinates
# 0  MultiPolygon  [[[[77.5922939, 13.0971962], [77.5909447, 13.0...
# ...

# %%
df.isnull().sum()
# Out:
# type                       0
# properties.WARD_NO         0
# properties.WARD_NAME       0
# properties.MOVEMENT_ID     0
# properties.DISPLAY_NAME    0
# geometry.type              0
# geometry.coordinates       0
# dtype: int64
